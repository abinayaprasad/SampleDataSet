# %%
import pandas as pd
ds = pd.read_excel(r'E:\Datatrained\datasets\Employee_DS.xlsx')
ds
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0      EmplID   EmplName        Age     Gender     Salary
# 1           1          A         30          F      30000
# 2           2          B         31          M      30000
# 3           3          C         32          F      30000
# 4           4          D         33          F      30000
# 5           5          E         34          M      30000
# 6           6          F         35          F      30000
# 7           7          G         36          F      30000
# 8           8          H         37          M      30000
# 9           9          I         38          F      30000
# 10         10          J         39          F      30000
# 11         11          K         40          M      30000
# 12         12          L         41          F      30000
# 13         13          M         42          F      30000
# 14         14          N         43          M      30000

# %%
import pandas as pd
df = pd.read_csv(r'E:\Datatrained\datasets\reddit_vm.csv')
df
# Out:
#                                                   title  score       id  \
# 0     Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1     COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2     Coronavirus variants could fuel Canada's third...      6   lohlle
# 3     Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4     Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# ...                                                 ...    ...      ...
# 1580                                            Comment      2  elrlyvd
# 1581                                            Comment      1  elrl1ur
# 1582                                            Comment      1  elrki11
# 1583                                            Comment      1  elrjamk
# 1584                                            Comment      3  elris5z
#
#                                                     url  comms_num  \
# ...
